# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Creando Arrays

# %%
a1 = np.array([3,5,7,3])
a2 = np.zeros(10)
a3 = np.ones(10)
a4 = np.random.random(1000)
a5 = np.random.rand(1000)
a6 = np.linspace(0, 10, 100)
a7 = np.arange(0, 10, 0.02)
a8 = np.random.normal(0,1, 1000)

# %%
x = np.linspace(0,1,100)
y = x**2

# %% [markdown]
# # Operaciones

# %%
2*a1
# Out:
# array([ 6, 10, 14,  6])

# %%
1/a1
# Out:
# array([0.33333333, 0.2       , 0.14285714, 0.33333333])

# %%
a1>4
# Out:
# array([False,  True,  True, False])

# %%
a1[a1>4]
# Out:
# array([5, 7])

# %%
1/a1 + 2 + a1
# Out:
# array([5.33333333, 7.2       , 9.14285714, 5.33333333])

# %%
plt.plot(x, y)

# %%
np.histogram(a8)
# Out:
# (array([  6,  32,  75, 177, 255, 225, 145,  57,  25,   3]),
#  array([-3.07852932, -2.43863093, -1.79873253, -1.15883414, -0.51893574,
#          0.12096265,  0.76086105,  1.40075944,  2.04065784,  2.68055623,
#          3.32045463]))

# %%
hist, bins  = np.histogram(a8, bins=20)
print(hist)
print('='*50)
print(bins)
# Out:
# [  3   3  10  22  31  44  68 109 133 122 124 101  84  61  45  12  16   9
#    2   1]
# ...
# [-3.07852932 -2.75858013 -2.43863093 -2.11868173 -1.79873253 -1.47878334
#  -1.15883414 -0.83888494 -0.51893574 -0.19898655  0.12096265  0.44091185
#   0.76086105  1.08081024  1.40075944  1.72070864  2.04065784  2.36060704
#   2.68055623  3.00050543  3.32045463]

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(bins[:-1], hist, "o-", linewidth=2.0)
plt.show()

# %%
def f(x):
    return x**2 * np.sin(x) / np.exp(-x)

# %%
x = np.linspace(0,10,100)
y = f(x)

# %%
plt.figure()
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Array Indexing/Slicing

# %%
a1 = np.array([2,4,6,8,100])
a1
# Out:
# array([  2,   4,   6,   8, 100])

# %%
a1[2]
# Out:
# 6

# %%
a1[2:]
# Out:
# array([  6,   8, 100])

# %%
a1[:-2]
# Out:
# array([2, 4, 6])

# %%
a1[1:-2]
# Out:
# array([4, 6])

# %%
a1[a1>3]
# Out:
# array([  4,   6,   8, 100])

# %%
names = np.array(['Ale','Max','Daniel','Andy','Amanda'])
names
# Out:
# array(['Ale', 'Max', 'Daniel', 'Andy', 'Amanda'], dtype='<U6')

# %%
primera_letra_M = np.vectorize(lambda s: s[0])(names)=="M"

# %%
primera_letra_M
# Out:
# array([False,  True, False, False, False])

# %%
names[primera_letra_M]
# Out:
# array(['Max'], dtype='<U6')

# %% [markdown]
# # Calculo / Funciones estadisticas

# %%
a1 = 2 * np.random.randn(10000)  + 10

# %%
np.std(a1)
# Out:
# 1.9775961353455447

# %%
np.mean(a1)
# Out:
# 9.950158742826547

# %%
np.percentile(a1, 80) # me dice el numero tal que el 80% son menores que ese numero ?Cuantos valores son 80% menos que un numero dado?
# Out:
# 11.629511637208115

# %% [markdown]
# ### Integrales y Derivadas

# %%
x = np.linspace(1,10,100)
y = 1/x**2 * np.sin(x)

# %%
plt.plot(x,y)

# %%
dxdy = np.gradient(y, x)

# %%
plt.plot(x,y)
plt.plot(x,dxdy)

# %%
y_int = np.cumsum(y) * (x[1] - x[0])

# %%
plt.plot(x,y)
plt.plot(x,dxdy)
plt.plot(x,y_int)

# %% [markdown]
# # Ejemplos Resueltos

# %% [markdown]
# ## Question 1:
# Let $y = e^{-x/10}\sin(x)$. Consider 10000 $x$ intervals in the range $[0, 10]$.
#
# 1. Plot the function $y$ vs. $x$ in the range $[0,10]$.
# 2. Compute the mean and standard deviation of $y$ for $x$ values in $[4,7]$.
# 3. For $x$ in the range $[4,7]$, find the value $y_m$ such that $80%$ of $y$ values are less than $y_m$
# 4. Plot $dy/dx$ vs. $x$
# 5. Find the locations where $dy/dx$ = 0.

# %%
# 1
N = 10000
x = np.linspace(0, 10, N+1)
y = np.exp(-x/10)*np.sin(x)

# %%
plt.plot(x, y)

# %%
# 2
y[(x>=4)*(x<=7)]
# Out:
# array([-0.50729988, -0.50768701, -0.50807354, ...,  0.32556559,
#         0.32590794,  0.32624989])

# %%
plt.plot(y[(x>=4)*(x<=7)])

# %%
print(f"Mean: {np.mean(y[(x>=4)*(x<=7)])} ------  Standard Deviation: {np.std(y[(x>=4)*(x<=7)])}")
# Out:
# Mean: -0.2956023068963138 ------  Standard Deviation: 0.3144875387508511

# %%
# 3
y[(x>=4)*(x<=7)]
# Out:
# array([-0.50729988, -0.50768701, -0.50807354, ...,  0.32556559,
#         0.32590794,  0.32624989])

# %%
print(f"y_m such 80% of the values are less than ym: {np.percentile(y[(x>=4)*(x<=7)], 80)}")
# Out:
# y_m such 80% of the values are less than ym: 0.06145551274590662

# %%
# 4
dydx = np.gradient(y, x)

# %%
plt.plot(x, y, 'b')
plt.plot(x,dydx, 'r')
plt.show()

# %%
# 5
dydx[1:]*dydx[:-1] < 0
# Out:
# array([False, False, False, ..., False, False, False])

# %%
x[1:][dydx[1:]*dydx[:-1] < 0]
# Out:
# array([1.472, 4.613, 7.755])

# %%
dydx[1:][dydx[1:]*dydx[:-1] < 0]
# Out:
# array([-0.00075665,  0.00017718, -0.00031792])

# %% [markdown]
# # Multi-Dimensional Arrays

# %%
a1 = np.array([[4,5,6],[1,2,2],[6,7,8]])
a1
# Out:
# array([[4, 5, 6],
#        [1, 2, 2],
#        [6, 7, 8]])

# %%
2/a1
# Out:
# array([[0.5       , 0.4       , 0.33333333],
#        [2.        , 1.        , 1.        ],
#        [0.33333333, 0.28571429, 0.25      ]])

# %%
a1.ravel()
# Out:
# array([4, 5, 6, 1, 2, 2, 6, 7, 8])

# %% [markdown]
# # 2D Functions

# %%
x = np.linspace(0, 10, 1000)
y = np.linspace(0, 5, 500)
z = x**2 + y**2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 3
#       1 x = np.linspace(0, 10, 1000)
#       2 y = np.linspace(0, 5, 500)
# ----> 3 z = x**2 + y**2
#
# ValueError: operands could not be broadcast together with shapes (1000,) (500,)

# %% [markdown]
# ### Necesitas usar meshgrids

# %%
xv, yv = np.meshgrid(x,y)

# %%
xv
# Out:
# array([[ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ],
#        [ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ],
#        [ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ],
#        ...,
#        [ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ],
#        [ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ],
#        [ 0.        ,  0.01001001,  0.02002002, ...,  9.97997998,
#          9.98998999, 10.        ]])

# %%
yv
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.01002004, 0.01002004, 0.01002004, ..., 0.01002004, 0.01002004,
#         0.01002004],
#        [0.02004008, 0.02004008, 0.02004008, ..., 0.02004008, 0.02004008,
#         0.02004008],
#        ...,
#        [4.97995992, 4.97995992, 4.97995992, ..., 4.97995992, 4.97995992,
#         4.97995992],
#        [4.98997996, 4.98997996, 4.98997996, ..., 4.98997996, 4.98997996,
#         4.98997996],
#        [5.        , 5.        , 5.        , ..., 5.        , 5.        ,
#         5.        ]])

# %%
zv = xv**2 + yv**2

# %%
zv
# Out:
# array([[0.00000000e+00, 1.00200300e-04, 4.00801202e-04, ...,
#         9.96000004e+01, 9.97999000e+01, 1.00000000e+02],
#        [1.00401203e-04, 2.00601504e-04, 5.01202405e-04, ...,
#         9.96001008e+01, 9.98000004e+01, 1.00000100e+02],
#        [4.01604813e-04, 5.01805113e-04, 8.02406014e-04, ...,
#         9.96004020e+01, 9.98003016e+01, 1.00000402e+02],
#        ...,
#        [2.48000008e+01, 2.48001010e+01, 2.48004016e+01, ...,
#         1.24400001e+02, 1.24599901e+02, 1.24800001e+02],
#        [2.48999000e+01, 2.49000002e+01, 2.49003008e+01, ...,
#         1.24499900e+02, 1.24699800e+02, 1.24899900e+02],
#        [2.50000000e+01, 2.50001002e+01, 2.50004008e+01, ...,
#         1.24600000e+02, 1.24799900e+02, 1.25000000e+02]])

# %%
plt.contourf(xv, yv, zv, levels=30)
plt.colorbar()

# %% [markdown]
# # Algebra basica

# %%
A = np.array([[3,2,1],[5,-5,4],[6,0,1]])
b1 = np.array([1,2,3])
b2 = np.array([-1,2,-5])

print(A)
# Out:
# [[ 3  2  1]
#  [ 5 -5  4]
#  [ 6  0  1]]

# %%
A @ b1
# Out:
# array([10,  7,  9])

# %%
A.T
# Out:
# array([[ 3,  5,  6],
#        [ 2, -5,  0],
#        [ 1,  4,  1]])

# %%
np.dot(b1, b2)
# Out:
# -12

# %%
np.cross(b1,b2)
# Out:
# array([-16,   2,   4])

# %% [markdown]
# # Sistema de ecuaciones
#
# $$3x+2y+z=4$$
# $$5x-5y+4z=3$$
# $$6x+z=0$$

# %%
A = np.array([[3,2,1],[5,-5,4],[6,0,1]])
c = np.array([4,3,0])

# %%
np.linalg.solve(A,c)
# Out:
# array([-0.49056604,  1.26415094,  2.94339623])

# %% [markdown]
# # Autovalores - Autovectores

# %%
A = np.array([[4,2,2],[2,4,2],[2,2,4]])
A
# Out:
# array([[4, 2, 2],
#        [2, 4, 2],
#        [2, 2, 4]])

# %%
np.linalg.eig(A)
# Out:
# EigResult(eigenvalues=array([2., 8., 2.]), eigenvectors=array([[-0.81649658,  0.57735027, -0.23513651],
#        [ 0.40824829,  0.57735027, -0.55958248],
#        [ 0.40824829,  0.57735027,  0.79471899]]))

# %%
w, v = np.linalg.eig(A)

# %%
w
# Out:
# array([2., 8., 2.])

# %%
v
# Out:
# array([[-0.81649658,  0.57735027, -0.23513651],
#        [ 0.40824829,  0.57735027, -0.55958248],
#        [ 0.40824829,  0.57735027,  0.79471899]])

# %%
v1 = v[:,0]
v1
# Out:
# array([-0.81649658,  0.40824829,  0.40824829])

# %%
A @ v1
# Out:
# array([-1.63299316,  0.81649658,  0.81649658])

# %%
w[0] * v1
# Out:
# array([-1.63299316,  0.81649658,  0.81649658])

# %% [markdown]
# # Ejemplo resuelto
#
# Let $f(x,y) = e^{-(x^2 + y^2)} \sin(x)$ for $-2 \leq x \leq 2$ and $-2 \leq y \leq 2$
#
# 1- Make a contour plot of $f$.
#
# 2- Find the volume $|f(x,y)|$ in the specified $x$ and $y$ range.
#
# 3- Find the volume $|f(x,y)|$ only in the region where $\sqrt{x^2 + y^2} > 0.5$.

# %%
# 1
x = np.linspace(-2, 2, 1000)
y = np.linspace(-2, 2, 1000)
xv, yv = np.meshgrid(x, y)
f = np.exp(-(xv**2 + yv**2)) * np.sin(xv)

# %%
f
# Out:
# array([[-0.00030504, -0.00031052, -0.00031609, ...,  0.00031609,
#          0.00031052,  0.00030504],
#        [-0.00030996, -0.00031553, -0.00032119, ...,  0.00032119,
#          0.00031553,  0.00030996],
#        [-0.00031494, -0.00032061, -0.00032636, ...,  0.00032636,
#          0.00032061,  0.00031494],
#        ...,
#        [-0.00031494, -0.00032061, -0.00032636, ...,  0.00032636,
#          0.00032061,  0.00031494],
#        [-0.00030996, -0.00031553, -0.00032119, ...,  0.00032119,
#          0.00031553,  0.00030996],
#        [-0.00030504, -0.00031052, -0.00031609, ...,  0.00031609,
#          0.00031052,  0.00030504]])

# %%
plt.contourf(xv, yv, f, levels = 100)
plt.colorbar()

# %%
# 2
np.abs(f.ravel()).sum() * np.diff(x)[0] * np.diff(y)[0]
# Out:
# 1.4861858145124311

# %%
# 3
xv**2 + yv**2  > 0.5**2
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
f[xv**2 + yv**2  > 0.5**2]
# Out:
# array([-0.00030504, -0.00031052, -0.00031609, ...,  0.00031609,
#         0.00031052,  0.00030504])

# %%
np.abs(f[xv**2 + yv**2  > 0.5**2].ravel()).sum() * np.diff(x)[0] * np.diff(y)[0]
# Out:
# 1.3447652930203164
